# %%
from typing import LiteralString
import requests

path: str = "/api/events/12"
base_url: str = "http://localhost:8002"
endpoint: LiteralString = f"{base_url}{path}"
endpoint
# Out:
# 'http://localhost:8002/api/events/12'

# %%
import requests
from requests import Response


response: Response = requests.get(endpoint)
if response.ok:
    data = response.json()
    print(data)
# Out:
# {'id': 12}
