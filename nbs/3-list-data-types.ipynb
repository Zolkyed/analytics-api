# %%
import requests
from pprint import pprint
path = "/api/events"
base_url = "http://localhost:8002"  # 127.0.0.1
endpoint = f"{base_url}{path}"
endpoint

# %%
response = requests.get(
    endpoint, params={'duration': '15 minutes', 'pages': []})
print('ok', response.ok)
if response.ok:
    data = response.json()
    pprint(data)
